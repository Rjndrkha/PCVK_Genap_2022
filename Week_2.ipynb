# %% [markdown]
# <a href="https://colab.research.google.com/github/Rjndrkha/PCVK_Genap_2022/blob/main/Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama  : Rajendra Rakha A P
#
# Kelas : 3H
#
# NIM    : 1941720080
#
#
# ---

# %%
from google.colab import drive
# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/kucing.jpeg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/kucing.jpeg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Rajendra',org=(10,500),fontFace=font,fontScale=4,color=(155,155,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R,G,B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# ---
#
#
# ### Task Section
#
# ---

# %% [markdown]
# Number 1

# %%
plt.figure(figsize=(3,3))
plt.imshow(img3)

# %% [markdown]
# Number 2

# %%
img6 = img3
#Red - Green
img6[:,:,0] = np.zeros([img6.shape[0], img6.shape[1]])
plt.imshow(img6)

# %%
#Tugas 1 Green Blue
img_gb = img.copy()
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %% [markdown]
# Number 3

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3[10:100, 10:100])

# %% [markdown]
# Number 4

# %%
plt.imshow(img5[5:30])

# %% [markdown]
# Number 5

# %%
import random

img6 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
for x in range(5):
  startp = random.randint(0,350)
  endp = random.randint(0,350)

  c1 = random.randint(0,255)
  c2 = random.randint(0,255)
  c3 = random.randint(0,255)
  start_point = (startp , startp) 
    
  end_point = (endp, endp) 
    
  color = (c1, c2, c3) 
    
  thickness = 7
    
  img6 = cv.rectangle(img3, start_point, end_point, color, thickness) 
    
# Displaying the image  
plt.imshow(img6)

# %% [markdown]
# Number 6

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
imgme1 = cv.imread('/content/drive/MyDrive/PCVK/me.jpg')
imgme1 = cv.cvtColor(imgme1,cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(imgme1)

# %%
img_sc7 = imgme1
cv.rectangle(img_sc7,pt1=(600,1000),pt2=(1150,300),color=(255,255,255),thickness=5)
cv.circle(img_sc7,center=(850,550),radius=300,color=(255,0,0),thickness=5)
plt.imshow(img_sc7)

# %% [markdown]
# Number 7

# %%
img_sc10 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img_sc10,pt1=(0,400),pt2=(100,500),color=(0,0,255),thickness=3)
plt.imshow(img_sc10)

# %% [markdown]
# Number 8

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(imgme1,text='Rajendra',org=(10,1600),fontFace=font,fontScale=10,color=(255,0,0),thickness=10,lineType=cv.LINE_AA)
plt.imshow(imgme1)
